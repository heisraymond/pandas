# %% [markdown]
# # Intro to Dataframes

# %%
import pandas as pd 

df = pd.DataFrame([[1,2,3], [4,5,6], [7,8,9]], columns=["A", "B", "C"], index=["x", "y", "z"])
# You can specify the columns and indexes as shown above

# %%
# To see the first 5 rows
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
# To see the last 5 rows
df.tail()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
# To acsess columns
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
# To acsess indexes
df.index.to_list()
# Out:
# ['x', 'y', 'z']

# %%
# To get information about the dataframe
df.info()
"""
The output describes a pandas DataFrame with 3 rows (indexed x to z) and 3 columns (A, B, and C). 
All columns contain integer (int64) values with no missing data, and the entire DataFrame uses 
about 96 bytes of memory.
"""
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes
# '\nThe output describes a pandas DataFrame with 3 rows (indexed x to z) and 3 columns (A, B, and C). \nAll columns contain integer (int64) values with no missing data, and the entire DataFrame uses \nabout 96 bytes of memory.\n'

# %%
# To get summary statistical information about the data
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
# To find how many unique values are in each column
df.nunique()
# For specific column you can use df["A"].nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
# To know the shape of the dataframe (row x column)
df.shape
# Out:
# (3, 3)

# %%
# To know the number of items in the Dataframe
df.size
# Out:
# 9

# %% [markdown]
# # Loading in Dataframes from Files

# %%
weather = pd.read_csv('data/weather.csv')

weather.head()
# Out:
#    Unnamed: 0   data        date           param     siteid
# 0           1   0.00  2003-01-01   Precipitation       ACRE
# 1           2   0.00  2003-01-02   Precipitation  AlbertLea
# 2           3  11.32  2003-01-03   Precipitation       Ames
# 3           4   0.00  2003-01-04   Precipitation     Antigo
# 4           5   3.04  2003-01-05   Precipitation   Appleton

# %% [markdown]
# # Accessing Data with Pandas

# %%
# To get full summary of the data
# You can also access the first 10 (x) rows by weather.head(x)
weather
# Out:
#         Unnamed: 0   data        date                 param      siteid
# 0                1   0.00  2003-01-01         Precipitation        ACRE
# 1                2   0.00  2003-01-02         Precipitation   AlbertLea
# 2                3  11.32  2003-01-03         Precipitation        Ames
# 3                4   0.00  2003-01-04         Precipitation      Antigo
# 4                5   3.04  2003-01-05         Precipitation    Appleton
# ...            ...    ...         ...                   ...         ...
# 655357      655358  -1.96  2015-12-28   Minimum temperature       SEPAC
# 655358      655359  -3.86  2015-12-29   Minimum temperature     Seymour
# 655359      655360  -4.50  2015-12-30   Minimum temperature  Sutherland
# 655360      655361  -5.22  2015-12-31   Minimum temperature      Urbana
# 655361      655362  -8.23  2016-01-01   Minimum temperature    Walworth
#
# [655362 rows x 5 columns]

# %%
# To access random data
weather.sample(10)
# Out:
#         Unnamed: 0       data        date                 param     siteid
# 435303      435304  25.309999  2011-08-11   Maximum temperature  Arlington
# 373708      373709   4.740000  2011-12-31         Precipitation   Appleton
# 532703      532704  21.620001  2005-03-26   Maximum temperature  Manhattan
# 397837      397838  -7.220000  2013-01-18   Minimum temperature   MorrisMN
# 432888      432889   3.690000  2004-12-30   Maximum temperature   MorrisIL
# 349416      349417  27.580000  2010-07-02   Maximum temperature       ACRE
# 652052      652053  -6.300000  2006-12-10   Minimum temperature       Ames
# 563176      563177  22.180000  2010-08-26   Maximum temperature     Urbana
# 132973      132974   3.710000  2003-01-02   Maximum temperature      Perry
# 588611      588612   0.000000  2015-04-12         Precipitation      SEPAC

# %%
# To acess specific values using loc & iloc
# loc allows you to filter by rows and columns ie. weather.loc[[rows], [columns]]
weather.loc[[1,2,10], ["Unnamed: 0", "param"]]
# Out:
#     Unnamed: 0           param
# 1            2   Precipitation
# 2            3   Precipitation
# 10          11   Precipitation

# %%
# Using iloc (Integer Location)
"""
Definition:
.iloc (short for integer location) is used to access rows and columns in a DataFrame or Series 
by their integer position — similar to how you use list indexing in Python.

Key Points

Position-based indexer (uses numerical positions, not labels).
Can access single cells, entire rows, columns, or slices.
0-based indexing → first row/column is position 0.
End index in a slice is exclusive (like standard Python slicing).
Can handle lists, ranges, or boolean arrays for complex selections.

Can be used for both reading and writing data.

Syntax
df.iloc[row_index, column_index]

Element	Description
row_index	Row position(s) — int, list, slice, or boolean mask
column_index	Column position(s) — int, list, slice, or boolean mask

"""
# Getting a range of values 
weather.iloc[0:3,0]

# Getting a single row df.iloc[1]          

# Getting multiple rows df.iloc[0:2]        

# Getting specific rows and columns df.iloc[0:2, 0:2]  

# Getting non continious rows and columns df.iloc[[0, 2], [1, 2]]   

# Modify a value df.iloc[2, 1] = 23
# Out:
# 0    1
# 1    2
# 2    3
# Name: Unnamed: 0, dtype: int64

# %%
# A specific way to get more optimized values
"""
Definition:
.at is used to access or modify a single value in a DataFrame or Series using row and column labels.

Key Points:
Label-based scalar accessor (uses index labels and column names)
Optimized for fast single-value access — faster than .loc
Works only for one cell at a time (not slices or multiple rows/columns)
Commonly used for getting or setting a specific cell value

Syntax:
df.at[row_label, column_label]
"""
weather.at[1, "Unnamed: 0"]
# Out:
# np.int64(2)

# %%
# A specific way to get more optimized values
"""
Definition:
.iat is used to access or modify a single value in a DataFrame or Series using integer positions.

Key Points:
Position-based scalar accessor (uses row and column indices)
Optimized for fast single-value access — faster than .iloc
Works only for one cell at a time
Commonly used when working with numerical row and column positions

Syntax:
df.iat[row_index, column_index]
"""
weather.iat[4,0]
# Out:
# np.int64(5)

# %%
# Sortign values with pandas
# It is ascending by default
weather.sort_values(["data", "date"], ascending=[0,0])
# Out:
#         Unnamed: 0        data        date                 param        siteid
# 14870        14871  195.070007  2004-09-15         Precipitation  DixonSprings
# 500006      500007  180.020004  2006-09-23         Precipitation        Oceana
# 230712      230713  167.940002  2010-07-23         Precipitation     Lexington
# 231082      231083  155.330002  2011-07-28         Precipitation         McNay
# 189462      189463  155.070007  2014-08-22         Precipitation           PIT
# ...            ...         ...         ...                   ...           ...
# 75985        75986         NaN  2003-01-02   Maximum temperature     Rosemount
# 80734        80735         NaN  2003-01-02   Minimum temperature      Appleton
# 71235        71236         NaN  2003-01-01         Precipitation        Monroe
# 75984        75985         NaN  2003-01-01   Maximum temperature   Rhinelander
# 80733        80734         NaN  2003-01-01   Minimum temperature        Antigo
#
# [655362 rows x 5 columns]

# %%
# You can iterate b/n values in a dataframe using ofr loop
# This is not recomended as it consumes memory (Used 1m 57.8s)
for index, rows in weather.iterrows():
    print(index)
    print(rows)
# Out:
# 0
# Unnamed: 0                 1
# data                     0.0
# date              2003-01-01
# param          Precipitation
# siteid                  ACRE
# Name: 0, dtype: object
# 1
# Unnamed: 0                 2
# data                     0.0
# date              2003-01-02
# param          Precipitation
# siteid             AlbertLea
# Name: 1, dtype: object
# 2
# Unnamed: 0                 3
# data                   11.32
# date              2003-01-03
# param          Precipitation
# siteid                  Ames
# Name: 2, dtype: object
# 3
# Unnamed: 0                 4
# data                     0.0
# date              2003-01-04
# param          Precipitation
# siteid                Antigo
# Name: 3, dtype: object
# 4
# Unnamed: 0                 5
# data                    3.04
# date              2003-01-05
# param          Precipitation
# siteid              Appleton
# Name: 4, dtype: object
# 5
# Unnamed: 0                 6
# data                    0.49
# date              2003-01-06
# param          Precipitation
# siteid             Arlington
# Name: 5, dtype: object
# 6
# Unnamed: 0                 7
# data                     0.0
# date              2003-01-07
# param          Precipitation
# siteid             Bean&Beet
# Name: 6, dtype: object
# 7
# Unnamed: 0                 8
# data                     0.0
# date              2003-01-08
# param          Precipitation
# siteid             Brookings
# Name: 7, dtype: object
# 8
# Unnamed: 0                 9
# data                     0.0
# date              2003-01-09
# param          Precipitation
# siteid            Brownstown
# Name: 8, dtype: object
# 9
# Unnamed: 0                10
# data                     0.0
# date              2003-01-10
# param          Precipitation
# siteid              Columbia
# Name: 9, dtype: object
# 10
# Unnamed: 0                11
# data                     0.0
# date              2003-01-11
# param          Precipitation
# siteid             Crookston
# Name: 10, dtype: object
# 11
# Unnamed: 0                12
# data                     0.0
# date              2003-01-12
# param          Precipitation
# siteid                Dekalb
# Name: 11, dtype: object
# 12
# Unnamed: 0                13
# data                     0.0
# date              2003-01-13
# param          Precipitation
# siteid          DixonSprings
# Name: 12, dtype: object
# 13
# Unnamed: 0                14
# data                    1.05
# date              2003-01-14
# param          Precipitation
# siteid                  DPAC
# Name: 13, dtype: object
# 14
# Unnamed: 0                15
# data                     0.0
# date              2003-01-15
# param          Precipitation
# siteid           EastLansing
# Name: 14, dtype: object
# 15
# Unnamed: 0                16
# data                     0.2
# date              2003-01-16
# param          Precipitation
# siteid             EauClaire
# Name: 15, dtype: object
# 16
# Unnamed: 0                17
# data                    1.28
# date              2003-01-17
# param          Precipitation
# siteid              Freeport
# Name: 16, dtype: object
# 17
# Unnamed: 0                18
# data                     0.0
# date              2003-01-18
# param          Precipitation
# siteid               Hancock
# Name: 17, dtype: object
# 18
# Unnamed: 0                19
# data                    0.73
# date              2003-01-19
# param          Precipitation
# siteid                Joilet
# Name: 18, dtype: object
# 19
# Unnamed: 0                20
# data                     1.1
# date              2003-01-20
# param          Precipitation
# siteid               Kellogg
# Name: 19, dtype: object
# 20
# Unnamed: 0                21
# data                     0.0
# date              2003-01-21
# param          Precipitation
# siteid             Lamberton
# Name: 20, dtype: object
# 21
# Unnamed: 0                22
# data                     0.0
# date              2003-01-22
# param          Precipitation
# siteid             Lancaster
# Name: 21, dtype: object
# 22
# Unnamed: 0                23
# data                     0.0
# date              2003-01-23
# param          Precipitation
# siteid             Lexington
# Name: 22, dtype: object
# 23
# Unnamed: 0                24
# data                     0.0
# date              2003-01-24
# param          Precipitation
# siteid             Manhattan
# Name: 23, dtype: object
# 24
# Unnamed: 0                25
# data                     0.0
# date              2003-01-25
# param          Precipitation
# siteid                 McNay
# Name: 24, dtype: object
# 25
# Unnamed: 0                26
# data                    2.12
# date              2003-01-26
# param          Precipitation
# siteid              Metamora
# Name: 25, dtype: object
# 26
# Unnamed: 0                27
# data                     0.0
# date              2003-01-27
# param          Precipitation
# siteid              Monmouth
# Name: 26, dtype: object
# 27
# Unnamed: 0                28
# data                     0.0
# date              2003-01-28
# param          Precipitation
# siteid                Monroe
# Name: 27, dtype: object
# 28
# Unnamed: 0                29
# data                    4.44
# date              2003-01-29
# param          Precipitation
# siteid              MorrisIL
# Name: 28, dtype: object
# 29
# Unnamed: 0                30
# data                     0.0
# date              2003-01-30
# param          Precipitation
# siteid              MorrisMN
# Name: 29, dtype: object
# 30
# Unnamed: 0                31
# data                    0.34
# date              2003-01-31
# param          Precipitation
# siteid                Nashua
# Name: 30, dtype: object
# 31
# Unnamed: 0                32
# data                    5.65
# date              2003-02-01
# param          Precipitation
# siteid                 NEPAC
# Name: 31, dtype: object
# 32
# Unnamed: 0                33
# data                    1.53
# date              2003-02-02
# param          Precipitation
# siteid                Oceana
# Name: 32, dtype: object
# 33
# Unnamed: 0                34
# data                     0.0
# date              2003-02-03
# param          Precipitation
# siteid                 Perry
# Name: 33, dtype: object
# 34
# Unnamed: 0                35
# data                     6.6
# date              2003-02-04
# param          Precipitation
# siteid                   PIT
# Name: 34, dtype: object
# 35
# Unnamed: 0                36
# data                     0.0
# date              2003-02-05
# param          Precipitation
# siteid          Portageville
# Name: 35, dtype: object
# 36
# Unnamed: 0                37
# data                    0.49
# date              2003-02-06
# param          Precipitation
# siteid                  PPAC
# Name: 36, dtype: object
# 37
# Unnamed: 0                38
# data                    0.31
# date              2003-02-07
# param          Precipitation
# siteid             Princeton
# Name: 37, dtype: object
# 38
# Unnamed: 0                39
# data                     0.0
# date              2003-02-08
# param          Precipitation
# siteid           Rhinelander
# Name: 38, dtype: object
# 39
# Unnamed: 0                40
# data                     0.0
# date              2003-02-09
# param          Precipitation
# siteid             Rosemount
# Name: 39, dtype: object
# 40
# Unnamed: 0                41
# data                    0.85
# date              2003-02-10
# param          Precipitation
# siteid               Sanilac
# Name: 40, dtype: object
# 41
# Unnamed: 0                42
# data                    0.74
# date              2003-02-11
# param          Precipitation
# siteid                 SEPAC
# Name: 41, dtype: object
# 42
# Unnamed: 0                43
# data                     0.0
# date              2003-02-12
# param          Precipitation
# siteid               Seymour
# Name: 42, dtype: object
# 43
# Unnamed: 0                44
# data                     0.0
# date              2003-02-13
# param          Precipitation
# siteid            Sutherland
# Name: 43, dtype: object
# 44
# Unnamed: 0                45
# data                     0.0
# date              2003-02-14
# param          Precipitation
# siteid                Urbana
# Name: 44, dtype: object
# 45
# Unnamed: 0                46
# data                    7.24
# date              2003-02-15
# param          Precipitation
# siteid              Walworth
# Name: 45, dtype: object
# 46
# Unnamed: 0                47
# data                    0.58
# date              2003-02-16
# param          Precipitation
# siteid                  ACRE
# Name: 46, dtype: object
# 47
# Unnamed: 0                48
# data                     0.0
# date              2003-02-17
# param          Precipitation
# siteid             AlbertLea
# Name: 47, dtype: object
# 48
# Unnamed: 0                49
# data                     0.0
# date              2003-02-18
# param          Precipitation
# siteid                  Ames
# Name: 48, dtype: object
# 49
# Unnamed: 0                50
# data                     0.0
# date              2003-02-19
# param          Precipitation
# siteid                Antigo
# Name: 49, dtype: object
# 50
# Unnamed: 0                51
# data                     0.0
# date              2003-02-20
# param          Precipitation
# siteid              Appleton
# Name: 50, dtype: object
# 51
# Unnamed: 0                52
# data                     0.0
# date              2003-02-21
# param          Precipitation
# siteid             Arlington
# Name: 51, dtype: object
# 52
# Unnamed: 0                53
# data                    1.08
# date              2003-02-22
# param          Precipitation
# siteid             Bean&Beet
# Name: 52, dtype: object
# 53
# Unnamed: 0                54
# data                    3.02
# date              2003-02-23
# param          Precipitation
# siteid             Brookings
# Name: 53, dtype: object
# 54
# Unnamed: 0                55
# data                    1.58
# date              2003-02-24
# param          Precipitation
# siteid            Brownstown
# Name: 54, dtype: object
# 55
# Unnamed: 0                56
# data                     0.0
# date              2003-02-25
# param          Precipitation
# siteid              Columbia
# Name: 55, dtype: object
# 56
# Unnamed: 0                57
# data                     0.0
# date              2003-02-26
# param          Precipitation
# siteid             Crookston
# Name: 56, dtype: object
# 57
# Unnamed: 0                58
# data                     0.0
# date              2003-02-27
# param          Precipitation
# siteid                Dekalb
# Name: 57, dtype: object
# 58
# Unnamed: 0                59
# data                     0.0
# date              2003-02-28
# param          Precipitation
# siteid          DixonSprings
# Name: 58, dtype: object
# 59
# Unnamed: 0                60
# data                     0.0
# date              2003-03-01
# param          Precipitation
# siteid                  DPAC
# Name: 59, dtype: object
# 60
# Unnamed: 0                61
# data                    0.74
# date              2003-03-02
# param          Precipitation
# siteid           EastLansing
# Name: 60, dtype: object
# 61
# Unnamed: 0                62
# data                     0.0
# date              2003-03-03
# param          Precipitation
# siteid             EauClaire
# Name: 61, dtype: object
# 62
# Unnamed: 0                63
# data                     0.0
# date              2003-03-04
# param          Precipitation
# siteid              Freeport
# Name: 62, dtype: object
# 63
# Unnamed: 0                64
# data                    1.21
# date              2003-03-05
# param          Precipitation
# siteid               Hancock
# Name: 63, dtype: object
# 64
# Unnamed: 0                65
# data                    1.11
# date              2003-03-06
# param          Precipitation
# siteid                Joilet
# Name: 64, dtype: object
# 65
# Unnamed: 0                66
# data                     0.0
# date              2003-03-07
# param          Precipitation
# siteid               Kellogg
# Name: 65, dtype: object
# 66
# Unnamed: 0                67
# data                     0.0
# date              2003-03-08
# param          Precipitation
# siteid             Lamberton
# Name: 66, dtype: object
# 67
# Unnamed: 0                68
# data                     0.0
# date              2003-03-09
# param          Precipitation
# siteid             Lancaster
# Name: 67, dtype: object
# 68
# Unnamed: 0                69
# data                     0.0
# date              2003-03-10
# param          Precipitation
# siteid             Lexington
# Name: 68, dtype: object
# 69
# Unnamed: 0                70
# data                     0.0
# date              2003-03-11
# param          Precipitation
# siteid             Manhattan
# Name: 69, dtype: object
# 70
# Unnamed: 0                71
# data                     0.0
# date              2003-03-12
# param          Precipitation
# siteid                 McNay
# Name: 70, dtype: object
# 71
# Unnamed: 0                72
# data                    3.86
# date              2003-03-13
# param          Precipitation
# siteid              Metamora
# Name: 71, dtype: object
# 72
# Unnamed: 0                73
# data                     0.0
# date              2003-03-14
# param          Precipitation
# siteid              Monmouth
# Name: 72, dtype: object
# 73
# Unnamed: 0                74
# data                     0.0
# date              2003-03-15
# param          Precipitation
# siteid                Monroe
# Name: 73, dtype: object
# 74
# Unnamed: 0                75
# data                     0.0
# date              2003-03-16
# param          Precipitation
# siteid              MorrisIL
# Name: 74, dtype: object
# 75
# Unnamed: 0                76
# data                     0.0
# date              2003-03-17
# param          Precipitation
# siteid              MorrisMN
# Name: 75, dtype: object
# 76
# Unnamed: 0                77
# data                     0.0
# date              2003-03-18
# param          Precipitation
# siteid                Nashua
# Name: 76, dtype: object
# 77
# Unnamed: 0                78
# data                     2.2
# date              2003-03-19
# param          Precipitation
# siteid                 NEPAC
# Name: 77, dtype: object
# 78
# Unnamed: 0                79
# data                    0.58
# date              2003-03-20
# param          Precipitation
# siteid                Oceana
# Name: 78, dtype: object
# 79
# Unnamed: 0                80
# data                    8.63
# date              2003-03-21
# param          Precipitation
# siteid                 Perry
# Name: 79, dtype: object
# 80
# Unnamed: 0                81
# data                     0.0
# date              2003-03-22
# param          Precipitation
# siteid                   PIT
# Name: 80, dtype: object
# 81
# Unnamed: 0                82
# data                     0.0
# date              2003-03-23
# param          Precipitation
# siteid          Portageville
# Name: 81, dtype: object
# 82
# Unnamed: 0                83
# data                     0.0
# date              2003-03-24
# param          Precipitation
# siteid                  PPAC
# Name: 82, dtype: object
# 83
# Unnamed: 0                84
# data                    1.49
# date              2003-03-25
# param          Precipitation
# siteid             Princeton
# Name: 83, dtype: object
# 84
# Unnamed: 0                85
# data                     0.0
# date              2003-03-26
# param          Precipitation
# siteid           Rhinelander
# Name: 84, dtype: object
# 85
# Unnamed: 0                86
# data                     0.0
# date              2003-03-27
# param          Precipitation
# siteid             Rosemount
# Name: 85, dtype: object
# 86
# Unnamed: 0                87
# data                    1.67
# date              2003-03-28
# param          Precipitation
# siteid               Sanilac
# Name: 86, dtype: object
# 87
# Unnamed: 0                88
# data                     0.4
# date              2003-03-29
# param          Precipitation
# siteid                 SEPAC
# Name: 87, dtype: object
# 88
# Unnamed: 0                89
# data                     0.0
# date              2003-03-30
# param          Precipitation
# siteid               Seymour
# Name: 88, dtype: object
# 89
# Unnamed: 0                90
# data                     0.0
# date              2003-03-31
# param          Precipitation
# siteid            Sutherland
# Name: 89, dtype: object
# 90
# Unnamed: 0                91
# data                    0.76
# date              2003-04-01
# param          Precipitation
# siteid                Urbana
# Name: 90, dtype: object
# 91
# Unnamed: 0                92
# data                     0.0
# date              2003-04-02
# param          Precipitation
# siteid              Walworth
# Name: 91, dtype: object
# 92
# Unnamed: 0                93
# data                     0.0
# date              2003-04-03
# param          Precipitation
# siteid                  ACRE
# Name: 92, dtype: object
# 93
# Unnamed: 0                94
# data                    1.21
# date              2003-04-04
# param          Precipitation
# siteid             AlbertLea
# Name: 93, dtype: object
# 94
# Unnamed: 0                95
# data                   26.52
# date              2003-04-05
# param          Precipitation
# siteid                  Ames
# Name: 94, dtype: object
# 95
# Unnamed: 0                96
# data                     0.0
# date              2003-04-06
# param          Precipitation
# siteid                Antigo
# Name: 95, dtype: object
# 96
# Unnamed: 0                97
# data                    9.29
# date              2003-04-07
# param          Precipitation
# siteid              Appleton
# Name: 96, dtype: object
# 97
# Unnamed: 0                98
# data                     0.0
# date              2003-04-08
# param          Precipitation
# siteid             Arlington
# Name: 97, dtype: object
# 98
# Unnamed: 0                99
# data                     0.0
# date              2003-04-09
# param          Precipitation
# siteid             Bean&Beet
# Name: 98, dtype: object
# 99
# Unnamed: 0               100
# data                     0.0
# date              2003-04-10
# param          Precipitation
# siteid             Brookings
# Name: 99, dtype: object
# 100
# Unnamed: 0               101
# data                     0.0
# date              2003-04-11
# param          Precipitation
# siteid            Brownstown
# Name: 100, dtype: object
# 101
# Unnamed: 0               102
# data                     0.0
# date              2003-04-12
# param          Precipitation
# siteid              Columbia
# Name: 101, dtype: object
# 102
# Unnamed: 0               103
# data                     0.0
# date              2003-04-13
# param          Precipitation
# siteid             Crookston
# Name: 102, dtype: object
# 103
# Unnamed: 0               104
# data                     0.0
# date              2003-04-14
# param          Precipitation
# siteid                Dekalb
# Name: 103, dtype: object
# 104
# Unnamed: 0               105
# data                     0.0
# date              2003-04-15
# param          Precipitation
# siteid          DixonSprings
# Name: 104, dtype: object
# 105
# Unnamed: 0               106
# data                     0.0
# date              2003-04-16
# param          Precipitation
# siteid                  DPAC
# Name: 105, dtype: object
# 106
# Unnamed: 0               107
# data                    0.77
# date              2003-04-17
# param          Precipitation
# siteid           EastLansing
# Name: 106, dtype: object
# 107
# Unnamed: 0               108
# data                    0.62
# date              2003-04-18
# param          Precipitation
# siteid             EauClaire
# Name: 107, dtype: object
# 108
# Unnamed: 0               109
# data                     0.0
# date              2003-04-19
# param          Precipitation
# siteid              Freeport
# Name: 108, dtype: object
# 109
# Unnamed: 0               110
# data                    6.93
# date              2003-04-20
# param          Precipitation
# siteid               Hancock
# Name: 109, dtype: object
# 110
# Unnamed: 0               111
# data                    4.18
# date              2003-04-21
# param          Precipitation
# siteid                Joilet
# Name: 110, dtype: object
# 111
# Unnamed: 0               112
# data                    0.89
# date              2003-04-22
# param          Precipitation
# siteid               Kellogg
# Name: 111, dtype: object
# 112
# Unnamed: 0               113
# data                     0.0
# date              2003-04-23
# param          Precipitation
# siteid             Lamberton
# Name: 112, dtype: object
# 113
# Unnamed: 0               114
# data                     0.0
# date              2003-04-24
# param          Precipitation
# siteid             Lancaster
# Name: 113, dtype: object
# 114
# Unnamed: 0               115
# data                    3.29
# date              2003-04-25
# param          Precipitation
# siteid             Lexington
# Name: 114, dtype: object
# 115
# Unnamed: 0               116
# data                    7.65
# date              2003-04-26
# param          Precipitation
# siteid             Manhattan
# Name: 115, dtype: object
# 116
# Unnamed: 0               117
# data                     0.0
# date              2003-04-27
# param          Precipitation
# siteid                 McNay
# Name: 116, dtype: object
# 117
# Unnamed: 0               118
# data                     0.0
# date              2003-04-28
# param          Precipitation
# siteid              Metamora
# Name: 117, dtype: object
# 118
# Unnamed: 0               119
# data                    8.99
# date              2003-04-29
# param          Precipitation
# siteid              Monmouth
# Name: 118, dtype: object
# 119
# Unnamed: 0               120
# data                     0.0
# date              2003-04-30
# param          Precipitation
# siteid                Monroe
# Name: 119, dtype: object
# 120
# Unnamed: 0               121
# data                    7.26
# date              2003-05-01
# param          Precipitation
# siteid              MorrisIL
# Name: 120, dtype: object
# 121
# Unnamed: 0               122
# data                    21.5
# date              2003-05-02
# param          Precipitation
# siteid              MorrisMN
# Name: 121, dtype: object
# 122
# Unnamed: 0               123
# data                     0.0
# date              2003-05-03
# param          Precipitation
# siteid                Nashua
# Name: 122, dtype: object
# 123
# Unnamed: 0               124
# data                     0.0
# date              2003-05-04
# param          Precipitation
# siteid                 NEPAC
# Name: 123, dtype: object
# 124
# Unnamed: 0               125
# data               52.880001
# date              2003-05-05
# param          Precipitation
# siteid                Oceana
# Name: 124, dtype: object
# 125
# Unnamed: 0               126
# data                     0.0
# date              2003-05-06
# param          Precipitation
# siteid                 Perry
# Name: 125, dtype: object
# 126
# Unnamed: 0               127
# data                    1.21
# date              2003-05-07
# param          Precipitation
# siteid                   PIT
# Name: 126, dtype: object
# 127
# Unnamed: 0               128
# data                    0.59
# date              2003-05-08
# param          Precipitation
# siteid          Portageville
# Name: 127, dtype: object
# 128
# Unnamed: 0               129
# data                    8.21
# date              2003-05-09
# param          Precipitation
# siteid                  PPAC
# Name: 128, dtype: object
# 129
# Unnamed: 0               130
# data                    4.11
# date              2003-05-10
# param          Precipitation
# siteid             Princeton
# Name: 129, dtype: object
# 130
# Unnamed: 0               131
# data                   14.99
# date              2003-05-11
# param          Precipitation
# siteid           Rhinelander
# Name: 130, dtype: object
# 131
# Unnamed: 0               132
# data                     0.0
# date              2003-05-12
# param          Precipitation
# siteid             Rosemount
# Name: 131, dtype: object
# 132
# Unnamed: 0               133
# data                     0.0
# date              2003-05-13
# param          Precipitation
# siteid               Sanilac
# Name: 132, dtype: object
# 133
# Unnamed: 0               134
# data                     0.0
# date              2003-05-14
# param          Precipitation
# siteid                 SEPAC
# Name: 133, dtype: object
# 134
# Unnamed: 0               135
# data                   16.85
# date              2003-05-15
# param          Precipitation
# siteid               Seymour
# Name: 134, dtype: object
# 135
# Unnamed: 0               136
# data                     0.0
# date              2003-05-16
# param          Precipitation
# siteid            Sutherland
# Name: 135, dtype: object
# 136
# Unnamed: 0               137
# data                     0.0
# date              2003-05-17
# param          Precipitation
# siteid                Urbana
# Name: 136, dtype: object
# 137
# Unnamed: 0               138
# data                    0.41
# date              2003-05-18
# param          Precipitation
# siteid              Walworth
# Name: 137, dtype: object
# 138
# Unnamed: 0               139
# data                     0.0
# date              2003-05-19
# param          Precipitation
# siteid                  ACRE
# Name: 138, dtype: object
# 139
# Unnamed: 0               140
# data                    5.59
# date              2003-05-20
# param          Precipitation
# siteid             AlbertLea
# Name: 139, dtype: object
# 140
# Unnamed: 0               141
# data                    0.49
# date              2003-05-21
# param          Precipitation
# siteid                  Ames
# Name: 140, dtype: object
# 141
# Unnamed: 0               142
# data                     0.0
# date              2003-05-22
# param          Precipitation
# siteid                Antigo
# Name: 141, dtype: object
# 142
# Unnamed: 0               143
# data                     0.0
# date              2003-05-23
# param          Precipitation
# siteid              Appleton
# Name: 142, dtype: object
# 143
# Unnamed: 0               144
# data                     0.0
# date              2003-05-24
# param          Precipitation
# siteid             Arlington
# Name: 143, dtype: object
# 144
# Unnamed: 0               145
# data                     0.0
# date              2003-05-25
# param          Precipitation
# siteid             Bean&Beet
# Name: 144, dtype: object
# 145
# Unnamed: 0               146
# data                     0.0
# date              2003-05-26
# param          Precipitation
# siteid             Brookings
# Name: 145, dtype: object
# 146
# Unnamed: 0               147
# data                     0.0
# date              2003-05-27
# param          Precipitation
# siteid            Brownstown
# Name: 146, dtype: object
# 147
# Unnamed: 0               148
# data                     0.0
# date              2003-05-28
# param          Precipitation
# siteid              Columbia
# Name: 147, dtype: object
# 148
# Unnamed: 0               149
# data               18.129999
# date              2003-05-29
# param          Precipitation
# siteid             Crookston
# Name: 148, dtype: object
# 149
# Unnamed: 0               150
# data                     0.0
# date              2003-05-30
# param          Precipitation
# siteid                Dekalb
# Name: 149, dtype: object
# 150
# Unnamed: 0               151
# data                   12.22
# date              2003-05-31
# param          Precipitation
# siteid          DixonSprings
# Name: 150, dtype: object
# 151
# Unnamed: 0               152
# data                     0.0
# date              2003-06-01
# param          Precipitation
# siteid                  DPAC
# Name: 151, dtype: object
# 152
# Unnamed: 0               153
# data                     0.0
# date              2003-06-02
# param          Precipitation
# siteid           EastLansing
# Name: 152, dtype: object
# 153
# Unnamed: 0               154
# data                    8.45
# date              2003-06-03
# param          Precipitation
# siteid             EauClaire
# Name: 153, dtype: object
# 154
# Unnamed: 0               155
# data                     0.0
# date              2003-06-04
# param          Precipitation
# siteid              Freeport
# Name: 154, dtype: object
# 155
# Unnamed: 0               156
# data                     0.0
# date              2003-06-05
# param          Precipitation
# siteid               Hancock
# Name: 155, dtype: object
# 156
# Unnamed: 0               157
# data                     0.0
# date              2003-06-06
# param          Precipitation
# siteid                Joilet
# Name: 156, dtype: object
# 157
# Unnamed: 0               158
# data                    2.05
# date              2003-06-07
# param          Precipitation
# siteid               Kellogg
# Name: 157, dtype: object
# 158
# Unnamed: 0               159
# data                     0.0
# date              2003-06-08
# param          Precipitation
# siteid             Lamberton
# Name: 158, dtype: object
# 159
# Unnamed: 0               160
# data                    0.71
# date              2003-06-09
# param          Precipitation
# siteid             Lancaster
# Name: 159, dtype: object
# 160
# Unnamed: 0               161
# data                     0.0
# date              2003-06-10
# param          Precipitation
# siteid             Lexington
# Name: 160, dtype: object
# 161
# Unnamed: 0               162
# data                    5.86
# date              2003-06-11
# param          Precipitation
# siteid             Manhattan
# Name: 161, dtype: object
# 162
# Unnamed: 0               163
# data               17.139999
# date              2003-06-12
# param          Precipitation
# siteid                 McNay
# Name: 162, dtype: object
# 163
# Unnamed: 0               164
# data                     0.0
# date              2003-06-13
# param          Precipitation
# siteid              Metamora
# Name: 163, dtype: object
# 164
# Unnamed: 0               165
# data               42.330002
# date              2003-06-14
# param          Precipitation
# siteid              Monmouth
# Name: 164, dtype: object
# 165
# Unnamed: 0               166
# data                     8.4
# date              2003-06-15
# param          Precipitation
# siteid                Monroe
# Name: 165, dtype: object
# 166
# Unnamed: 0               167
# data                     0.0
# date              2003-06-16
# param          Precipitation
# siteid              MorrisIL
# Name: 166, dtype: object
# 167
# Unnamed: 0               168
# data                     0.0
# date              2003-06-17
# param          Precipitation
# siteid              MorrisMN
# Name: 167, dtype: object
# 168
# Unnamed: 0               169
# data                     0.0
# date              2003-06-18
# param          Precipitation
# siteid                Nashua
# Name: 168, dtype: object
# 169
# Unnamed: 0               170
# data                    0.79
# date              2003-06-19
# param          Precipitation
# siteid                 NEPAC
# Name: 169, dtype: object
# 170
# Unnamed: 0               171
# data                     0.0
# date              2003-06-20
# param          Precipitation
# siteid                Oceana
# Name: 170, dtype: object
# 171
# Unnamed: 0               172
# data                     0.0
# date              2003-06-21
# param          Precipitation
# siteid                 Perry
# Name: 171, dtype: object
# 172
# Unnamed: 0               173
# data                     0.0
# date              2003-06-22
# param          Precipitation
# siteid                   PIT
# Name: 172, dtype: object
# 173
# Unnamed: 0               174
# data                     0.0
# date              2003-06-23
# param          Precipitation
# siteid          Portageville
# Name: 173, dtype: object
# 174
# Unnamed: 0               175
# data                     0.0
# date              2003-06-24
# param          Precipitation
# siteid                  PPAC
# Name: 174, dtype: object
# 175
# Unnamed: 0               176
# data                     0.0
# date              2003-06-25
# param          Precipitation
# siteid             Princeton
# Name: 175, dtype: object
# 176
# Unnamed: 0               177
# data                     0.0
# date              2003-06-26
# param          Precipitation
# siteid           Rhinelander
# Name: 176, dtype: object
# 177
# Unnamed: 0               178
# data                    0.84
# date              2003-06-27
# param          Precipitation
# siteid             Rosemount
# Name: 177, dtype: object
# 178
# Unnamed: 0               179
# data                     0.0
# date              2003-06-28
# param          Precipitation
# siteid               Sanilac
# Name: 178, dtype: object
# 179
# Unnamed: 0               180
# data                    3.71
# date              2003-06-29
# param          Precipitation
# siteid                 SEPAC
# Name: 179, dtype: object
# 180
# Unnamed: 0               181
# data                    1.05
# date              2003-06-30
# param          Precipitation
# siteid               Seymour
# Name: 180, dtype: object
# 181
# Unnamed: 0               182
# data                    2.61
# date              2003-07-01
# param          Precipitation
# siteid            Sutherland
# Name: 181, dtype: object
# 182
# Unnamed: 0               183
# data                    0.01
# date              2003-07-02
# param          Precipitation
# siteid                Urbana
# Name: 182, dtype: object
# 183
# Unnamed: 0               184
# data                     0.0
# date              2003-07-03
# param          Precipitation
# siteid              Walworth
# Name: 183, dtype: object
# 184
# Unnamed: 0               185
# data                     0.0
# date              2003-07-04
# param          Precipitation
# siteid                  ACRE
# Name: 184, dtype: object
# 185
# Unnamed: 0               186
# data               22.120001
# date              2003-07-05
# param          Precipitation
# siteid             AlbertLea
# Name: 185, dtype: object
# 186
# Unnamed: 0               187
# data               38.869999
# date              2003-07-06
# param          Precipitation
# siteid                  Ames
# Name: 186, dtype: object
# 187
# Unnamed: 0               188
# data               20.059999
# date              2003-07-07
# param          Precipitation
# siteid                Antigo
# Name: 187, dtype: object
# 188
# Unnamed: 0               189
# data                   12.86
# date              2003-07-08
# param          Precipitation
# siteid              Appleton
# Name: 188, dtype: object
# 189
# Unnamed: 0               190
# data               28.709999
# date              2003-07-09
# param          Precipitation
# siteid             Arlington
# Name: 189, dtype: object
# 190
# Unnamed: 0               191
# data                   24.09
# date              2003-07-10
# param          Precipitation
# siteid             Bean&Beet
# Name: 190, dtype: object
# 191
# Unnamed: 0               192
# data                     0.0
# date              2003-07-11
# param          Precipitation
# siteid             Brookings
# Name: 191, dtype: object
# 192
# Unnamed: 0               193
# data                   13.59
# date              2003-07-12
# param          Precipitation
# siteid            Brownstown
# Name: 192, dtype: object
# 193
# Unnamed: 0               194
# data                     0.0
# date              2003-07-13
# param          Precipitation
# siteid              Columbia
# Name: 193, dtype: object
# 194
# Unnamed: 0               195
# data                     0.0
# date              2003-07-14
# param          Precipitation
# siteid             Crookston
# Name: 194, dtype: object
# 195
# Unnamed: 0               196
# data                     0.0
# date              2003-07-15
# param          Precipitation
# siteid                Dekalb
# Name: 195, dtype: object
# 196
# Unnamed: 0               197
# data                   11.81
# date              2003-07-16
# param          Precipitation
# siteid          DixonSprings
# Name: 196, dtype: object
# 197
# Unnamed: 0               198
# data                     0.0
# date              2003-07-17
# param          Precipitation
# siteid                  DPAC
# Name: 197, dtype: object
# 198
# Unnamed: 0               199
# data                    7.02
# date              2003-07-18
# param          Precipitation
# siteid           EastLansing
# Name: 198, dtype: object
# 199
# Unnamed: 0               200
# data                     0.0
# date              2003-07-19
# param          Precipitation
# siteid             EauClaire
# Name: 199, dtype: object
# 200
# Unnamed: 0               201
# data                     0.0
# date              2003-07-20
# param          Precipitation
# siteid              Freeport
# Name: 200, dtype: object
# 201
# Unnamed: 0               202
# data                   16.75
# date              2003-07-21
# param          Precipitation
# siteid               Hancock
# Name: 201, dtype: object
# 202
# Unnamed: 0               203
# data                    3.22
# date              2003-07-22
# param          Precipitation
# siteid                Joilet
# Name: 202, dtype: object
# 203
# Unnamed: 0               204
# data                     0.0
# date              2003-07-23
# param          Precipitation
# siteid               Kellogg
# Name: 203, dtype: object
# 204
# Unnamed: 0               205
# data                    4.51
# date              2003-07-24
# param          Precipitation
# siteid             Lamberton
# Name: 204, dtype: object
# 205
# Unnamed: 0               206
# data                     0.0
# date              2003-07-25
# param          Precipitation
# siteid             Lancaster
# Name: 205, dtype: object
# 206
# Unnamed: 0               207
# data                     0.0
# date              2003-07-26
# param          Precipitation
# siteid             Lexington
# Name: 206, dtype: object
# 207
# Unnamed: 0               208
# data                     0.0
# date              2003-07-27
# param          Precipitation
# siteid             Manhattan
# Name: 207, dtype: object
# 208
# Unnamed: 0               209
# data                    2.61
# date              2003-07-28
# param          Precipitation
# siteid                 McNay
# Name: 208, dtype: object
# 209
# Unnamed: 0               210
# data                     4.8
# date              2003-07-29
# param          Precipitation
# siteid              Metamora
# Name: 209, dtype: object
# 210
# Unnamed: 0               211
# data                     0.0
# date              2003-07-30
# param          Precipitation
# siteid              Monmouth
# Name: 210, dtype: object
# 211
# Unnamed: 0               212
# data                     0.0
# date              2003-07-31
# param          Precipitation
# siteid                Monroe
# Name: 211, dtype: object
# 212
# Unnamed: 0               213
# data                     0.0
# date              2003-08-01
# param          Precipitation
# siteid              MorrisIL
# Name: 212, dtype: object
# 213
# Unnamed: 0               214
# data                     0.0
# date              2003-08-02
# param          Precipitation
# siteid              MorrisMN
# Name: 213, dtype: object
# 214
# Unnamed: 0               215
# data               16.549999
# date              2003-08-03
# param          Precipitation
# siteid                Nashua
# Name: 214, dtype: object
# 215
# Unnamed: 0               216
# data                    0.92
# date              2003-08-04
# param          Precipitation
# siteid                 NEPAC
# Name: 215, dtype: object
# 216
# Unnamed: 0               217
# data                     0.0
# date              2003-08-05
# param          Precipitation
# siteid                Oceana
# Name: 216, dtype: object
# 217
# Unnamed: 0               218
# data                     0.0
# date              2003-08-06
# param          Precipitation
# siteid                 Perry
# Name: 217, dtype: object
# 218
# Unnamed: 0               219
# data                     0.0
# date              2003-08-07
# param          Precipitation
# siteid                   PIT
# Name: 218, dtype: object
# 219
# Unnamed: 0               220
# data                     0.0
# date              2003-08-08
# param          Precipitation
# siteid          Portageville
# Name: 219, dtype: object
# 220
# Unnamed: 0               221
# data                    2.32
# date              2003-08-09
# param          Precipitation
# siteid                  PPAC
# Name: 220, dtype: object
# 221
# Unnamed: 0               222
# data                    8.57
# date              2003-08-10
# param          Precipitation
# siteid             Princeton
# Name: 221, dtype: object
# 222
# Unnamed: 0               223
# data                     0.0
# date              2003-08-11
# param          Precipitation
# siteid           Rhinelander
# Name: 222, dtype: object
# 223
# Unnamed: 0               224
# data                     0.0
# date              2003-08-12
# param          Precipitation
# siteid             Rosemount
# Name: 223, dtype: object
# 224
# Unnamed: 0               225
# data                     1.5
# date              2003-08-13
# param          Precipitation
# siteid               Sanilac
# Name: 224, dtype: object
# 225
# Unnamed: 0               226
# data                     0.0
# date              2003-08-14
# param          Precipitation
# siteid                 SEPAC
# Name: 225, dtype: object
# 226
# Unnamed: 0               227
# data                    1.18
# date              2003-08-15
# param          Precipitation
# siteid               Seymour
# Name: 226, dtype: object
# 227
# Unnamed: 0               228
# data                     0.0
# date              2003-08-16
# param          Precipitation
# siteid            Sutherland
# Name: 227, dtype: object
# 228
# Unnamed: 0               229
# data                     3.0
# date              2003-08-17
# param          Precipitation
# siteid                Urbana
# Name: 228, dtype: object
# 229
# Unnamed: 0               230
# data                     0.0
# date              2003-08-18
# param          Precipitation
# siteid              Walworth
# Name: 229, dtype: object
# 230
# Unnamed: 0               231
# data                     0.0
# date              2003-08-19
# param          Precipitation
# siteid                  ACRE
# Name: 230, dtype: object
# 231
# Unnamed: 0               232
# data                     0.0
# date              2003-08-20
# param          Precipitation
# siteid             AlbertLea
# Name: 231, dtype: object
# 232
# Unnamed: 0               233
# data                     0.0
# date              2003-08-21
# param          Precipitation
# siteid                  Ames
# Name: 232, dtype: object
# 233
# Unnamed: 0               234
# data                     0.0
# date              2003-08-22
# param          Precipitation
# siteid                Antigo
# Name: 233, dtype: object
# 234
# Unnamed: 0               235
# data                     0.0
# date              2003-08-23
# param          Precipitation
# siteid              Appleton
# Name: 234, dtype: object
# 235
# Unnamed: 0               236
# data                     0.0
# date              2003-08-24
# param          Precipitation
# siteid             Arlington
# Name: 235, dtype: object
# 236
# Unnamed: 0               237
# data                     0.0
# date              2003-08-25
# param          Precipitation
# siteid             Bean&Beet
# Name: 236, dtype: object
# 237
# Unnamed: 0               238
# data                     0.0
# date              2003-08-26
# param          Precipitation
# siteid             Brookings
# Name: 237, dtype: object
# 238
# Unnamed: 0               239
# data                     0.0
# date              2003-08-27
# param          Precipitation
# siteid            Brownstown
# Name: 238, dtype: object
# 239
# Unnamed: 0               240
# data                     0.0
# date              2003-08-28
# param          Precipitation
# siteid              Columbia
# Name: 239, dtype: object
# 240
# Unnamed: 0               241
# data                    7.64
# date              2003-08-29
# param          Precipitation
# siteid             Crookston
# Name: 240, dtype: object
# 241
# Unnamed: 0               242
# data               37.549999
# date              2003-08-30
# param          Precipitation
# siteid                Dekalb
# Name: 241, dtype: object
# 242
# Unnamed: 0               243
# data                     0.0
# date              2003-08-31
# param          Precipitation
# siteid          DixonSprings
# Name: 242, dtype: object
# 243
# Unnamed: 0               244
# data               68.040001
# date              2003-09-01
# param          Precipitation
# siteid                  DPAC
# Name: 243, dtype: object
# 244
# Unnamed: 0               245
# data                   17.99
# date              2003-09-02
# param          Precipitation
# siteid           EastLansing
# Name: 244, dtype: object
# 245
# Unnamed: 0               246
# data                    0.05
# date              2003-09-03
# param          Precipitation
# siteid             EauClaire
# Name: 245, dtype: object
# 246
# Unnamed: 0               247
# data                     0.0
# date              2003-09-04
# param          Precipitation
# siteid              Freeport
# Name: 246, dtype: object
# 247
# Unnamed: 0               248
# data                     0.0
# date              2003-09-05
# param          Precipitation
# siteid               Hancock
# Name: 247, dtype: object
# 248
# Unnamed: 0               249
# data                     0.0
# date              2003-09-06
# param          Precipitation
# siteid                Joilet
# Name: 248, dtype: object
# 249
# Unnamed: 0               250
# data                     0.0
# date              2003-09-07
# param          Precipitation
# siteid               Kellogg
# Name: 249, dtype: object
# 250
# Unnamed: 0               251
# data                     0.0
# date              2003-09-08
# param          Precipitation
# siteid             Lamberton
# Name: 250, dtype: object
# 251
# Unnamed: 0               252
# data                     0.0
# date              2003-09-09
# param          Precipitation
# siteid             Lancaster
# Name: 251, dtype: object
# 252
# Unnamed: 0               253
# data                     0.0
# date              2003-09-10
# param          Precipitation
# siteid             Lexington
# Name: 252, dtype: object
# 253
# Unnamed: 0               254
# data                     0.0
# date              2003-09-11
# param          Precipitation
# siteid             Manhattan
# Name: 253, dtype: object
# 254
# Unnamed: 0               255
# data                     0.0
# date              2003-09-12
# param          Precipitation
# siteid                 McNay
# Name: 254, dtype: object
# 255
# Unnamed: 0               256
# data                     0.0
# date              2003-09-13
# param          Precipitation
# siteid              Metamora
# Name: 255, dtype: object
# 256
# Unnamed: 0               257
# data                    8.34
# date              2003-09-14
# param          Precipitation
# siteid              Monmouth
# Name: 256, dtype: object
# 257
# Unnamed: 0               258
# data                     0.0
# date              2003-09-15
# param          Precipitation
# siteid                Monroe
# Name: 257, dtype: object
# 258
# Unnamed: 0               259
# data                    0.36
# date              2003-09-16
# param          Precipitation
# siteid              MorrisIL
# Name: 258, dtype: object
# 259
# Unnamed: 0               260
# data                     0.0
# date              2003-09-17
# param          Precipitation
# siteid              MorrisMN
# Name: 259, dtype: object
# 260
# Unnamed: 0               261
# data                     0.0
# date              2003-09-18
# param          Precipitation
# siteid                Nashua
# Name: 260, dtype: object
# 261
# Unnamed: 0               262
# data                     0.0
# date              2003-09-19
# param          Precipitation
# siteid                 NEPAC
# Name: 261, dtype: object
# 262
# Unnamed: 0               263
# data                     0.0
# date              2003-09-20
# param          Precipitation
# siteid                Oceana
# Name: 262, dtype: object
# 263
# Unnamed: 0               264
# data                     0.0
# date              2003-09-21
# param          Precipitation
# siteid                 Perry
# Name: 263, dtype: object
# 264
# Unnamed: 0               265
# data               20.370001
# date              2003-09-22
# param          Precipitation
# siteid                   PIT
# Name: 264, dtype: object
# 265
# Unnamed: 0               266
# data                    0.41
# date              2003-09-23
# param          Precipitation
# siteid          Portageville
# Name: 265, dtype: object
# 266
# Unnamed: 0               267
# data                   15.64
# date              2003-09-24
# param          Precipitation
# siteid                  PPAC
# Name: 266, dtype: object
# 267
# Unnamed: 0               268
# data               16.540001
# date              2003-09-25
# param          Precipitation
# siteid             Princeton
# Name: 267, dtype: object
# 268
# Unnamed: 0               269
# data                     0.0
# date              2003-09-26
# param          Precipitation
# siteid           Rhinelander
# Name: 268, dtype: object
# 269
# Unnamed: 0               270
# data               38.459999
# date              2003-09-27
# param          Precipitation
# siteid             Rosemount
# Name: 269, dtype: object
# 270
# Unnamed: 0               271
# data                     0.0
# date              2003-09-28
# param          Precipitation
# siteid               Sanilac
# Name: 270, dtype: object
# 271
# Unnamed: 0               272
# data                     0.0
# date              2003-09-29
# param          Precipitation
# siteid                 SEPAC
# Name: 271, dtype: object
# 272
# Unnamed: 0               273
# data                     0.0
# date              2003-09-30
# param          Precipitation
# siteid               Seymour
# Name: 272, dtype: object
# 273
# Unnamed: 0               274
# data                     0.0
# date              2003-10-01
# param          Precipitation
# siteid            Sutherland
# Name: 273, dtype: object
# 274
# Unnamed: 0               275
# data                     0.0
# date              2003-10-02
# param          Precipitation
# siteid                Urbana
# Name: 274, dtype: object
# 275
# Unnamed: 0               276
# data                     0.0
# date              2003-10-03
# param          Precipitation
# siteid              Walworth
# Name: 275, dtype: object
# 276
# Unnamed: 0               277
# data                    4.79
# date              2003-10-04
# param          Precipitation
# siteid                  ACRE
# Name: 276, dtype: object
# 277
# ...
# 14984
# Unnamed: 0             14985
# data                     0.0
# date              2005-01-07
# param          Precipitation
# siteid                   PIT
# Name: 14984, dtype: object
# 14985
# Unnamed: 0             14986
# data                     0.0
# date              2005-01-08
# param          Precipitation
# siteid          Portageville
# Name: 14985, dtype: object
# 14986
# Unnamed: 0             14987
# data                     0.0
# date              2005-01-09
# param          Precipitation
# siteid                  PPAC
# Name: 14986, dtype: object
# 14987
# Unnamed: 0             14988
# data                     0.0
# date              2005-01-10
# param          Precipitation
# siteid             Princeton
# Name: 14987, dtype: object
# 14988
# Unnamed: 0             14989
# data                     0.0
# date              2005-01-11
# param          Precipitation
# siteid           Rhinelander
# Name: 14988, dtype: object
# 14989
# Unnamed: 0             14990
# data                     0.0
# date              2005-01-12
# param          Precipitation
# siteid             Rosemount
# Name: 14989, dtype: object
# 14990
# Unnamed: 0             14991
# data                     0.0
# date              2005-01-13
# param          Precipitation
# siteid               Sanilac
# Name: 14990, dtype: object
# 14991
# Unnamed: 0             14992
# data                     0.0
# date              2005-01-14
# param          Precipitation
# siteid                 SEPAC
# Name: 14991, dtype: object
# 14992
# Unnamed: 0             14993
# data                     0.0
# date              2005-01-15
# param          Precipitation
# siteid               Seymour
# Name: 14992, dtype: object
# 14993
# Unnamed: 0             14994
# data                     0.0
# date              2005-01-16
# param          Precipitation
# siteid            Sutherland
# Name: 14993, dtype: object
# 14994
# Unnamed: 0             14995
# data                     0.0
# date              2005-01-17
# param          Precipitation
# siteid                Urbana
# Name: 14994, dtype: object
# 14995
# Unnamed: 0             14996
# data                     0.0
# date              2005-01-18
# param          Precipitation
# siteid              Walworth
# Name: 14995, dtype: object
# 14996
# Unnamed: 0             14997
# data                     0.0
# date              2005-01-19
# param          Precipitation
# siteid                  ACRE
# Name: 14996, dtype: object
# 14997
# Unnamed: 0             14998
# data                     0.0
# date              2005-01-20
# param          Precipitation
# siteid             AlbertLea
# Name: 14997, dtype: object
# 14998
# Unnamed: 0             14999
# data                     0.0
# date              2005-01-21
# param          Precipitation
# siteid                  Ames
# Name: 14998, dtype: object
# 14999
# Unnamed: 0             15000
# data                   12.38
# date              2005-01-22
# param          Precipitation
# siteid                Antigo
# Name: 14999, dtype: object
# 15000
# Unnamed: 0             15001
# data                     0.0
# date              2005-01-23
# param          Precipitation
# siteid              Appleton
# Name: 15000, dtype: object
# 15001
# Unnamed: 0             15002
# data                     0.0
# date              2005-01-24
# param          Precipitation
# siteid             Arlington
# Name: 15001, dtype: object
# 15002
# Unnamed: 0             15003
# data                     0.0
# date              2005-01-25
# param          Precipitation
# siteid             Bean&Beet
# Name: 15002, dtype: object
# 15003
# Unnamed: 0             15004
# data                     0.0
# date              2005-01-26
# param          Precipitation
# siteid             Brookings
# Name: 15003, dtype: object
# 15004
# Unnamed: 0             15005
# data                     0.0
# date              2005-01-27
# param          Precipitation
# siteid            Brownstown
# Name: 15004, dtype: object
# 15005
# Unnamed: 0             15006
# data                     0.0
# date              2005-01-28
# param          Precipitation
# siteid              Columbia
# Name: 15005, dtype: object
# 15006
# Unnamed: 0             15007
# data                     0.0
# date              2005-01-29
# param          Precipitation
# siteid             Crookston
# Name: 15006, dtype: object
# 15007
# Unnamed: 0             15008
# data                     0.0
# date              2005-01-30
# param          Precipitation
# siteid                Dekalb
# Name: 15007, dtype: object
# 15008
# Unnamed: 0             15009
# data                     0.0
# date              2005-01-31
# param          Precipitation
# siteid          DixonSprings
# Name: 15008, dtype: object
# 15009
# Unnamed: 0             15010
# data                     0.0
# date              2005-02-01
# param          Precipitation
# siteid                  DPAC
# Name: 15009, dtype: object
# 15010
# Unnamed: 0             15011
# data                     0.0
# date              2005-02-02
# param          Precipitation
# siteid           EastLansing
# Name: 15010, dtype: object
# 15011
# Unnamed: 0             15012
# data                     0.0
# date              2005-02-03
# param          Precipitation
# siteid             EauClaire
# Name: 15011, dtype: object
# 15012
# Unnamed: 0             15013
# data                     0.0
# date              2005-02-04
# param          Precipitation
# siteid              Freeport
# Name: 15012, dtype: object
# 15013
# Unnamed: 0             15014
# data                     0.0
# date              2005-02-05
# param          Precipitation
# siteid               Hancock
# Name: 15013, dtype: object
# 15014
# Unnamed: 0             15015
# data                    0.12
# date              2005-02-06
# param          Precipitation
# siteid                Joilet
# Name: 15014, dtype: object
# 15015
# Unnamed: 0             15016
# data                    4.99
# date              2005-02-07
# param          Precipitation
# siteid               Kellogg
# Name: 15015, dtype: object
# 15016
# Unnamed: 0             15017
# data                     0.0
# date              2005-02-08
# param          Precipitation
# siteid             Lamberton
# Name: 15016, dtype: object
# 15017
# Unnamed: 0             15018
# data                    1.19
# date              2005-02-09
# param          Precipitation
# siteid             Lancaster
# Name: 15017, dtype: object
# 15018
# Unnamed: 0             15019
# data                     0.0
# date              2005-02-10
# param          Precipitation
# siteid             Lexington
# Name: 15018, dtype: object
# 15019
# Unnamed: 0             15020
# data                     0.0
# date              2005-02-11
# param          Precipitation
# siteid             Manhattan
# Name: 15019, dtype: object
# 15020
# Unnamed: 0             15021
# data                     0.0
# date              2005-02-12
# param          Precipitation
# siteid                 McNay
# Name: 15020, dtype: object
# 15021
# Unnamed: 0             15022
# data                    0.67
# date              2005-02-13
# param          Precipitation
# siteid              Metamora
# Name: 15021, dtype: object
# 15022
# Unnamed: 0             15023
# data                   14.94
# date              2005-02-14
# param          Precipitation
# siteid              Monmouth
# Name: 15022, dtype: object
# 15023
# Unnamed: 0             15024
# data                     0.0
# date              2005-02-15
# param          Precipitation
# siteid                Monroe
# Name: 15023, dtype: object
# 15024
# Unnamed: 0             15025
# data                     0.0
# date              2005-02-16
# param          Precipitation
# siteid              MorrisIL
# Name: 15024, dtype: object
# 15025
# Unnamed: 0             15026
# data                     0.0
# date              2005-02-17
# param          Precipitation
# siteid              MorrisMN
# Name: 15025, dtype: object
# 15026
# Unnamed: 0             15027
# data                     0.0
# date              2005-02-18
# param          Precipitation
# siteid                Nashua
# Name: 15026, dtype: object
# 15027
# Unnamed: 0             15028
# data                     0.0
# date              2005-02-19
# param          Precipitation
# siteid                 NEPAC
# Name: 15027, dtype: object
# 15028
# Unnamed: 0             15029
# data                    6.09
# date              2005-02-20
# param          Precipitation
# siteid                Oceana
# Name: 15028, dtype: object
# 15029
# Unnamed: 0             15030
# data                    3.06
# date              2005-02-21
# param          Precipitation
# siteid                 Perry
# Name: 15029, dtype: object
# 15030
# Unnamed: 0             15031
# data                     0.0
# date              2005-02-22
# param          Precipitation
# siteid                   PIT
# Name: 15030, dtype: object
# 15031
# Unnamed: 0             15032
# data                     0.0
# date              2005-02-23
# param          Precipitation
# siteid          Portageville
# Name: 15031, dtype: object
# 15032
# Unnamed: 0             15033
# data                     0.0
# date              2005-02-24
# param          Precipitation
# siteid                  PPAC
# Name: 15032, dtype: object
# 15033
# Unnamed: 0             15034
# data                     0.0
# date              2005-02-25
# param          Precipitation
# siteid             Princeton
# Name: 15033, dtype: object
# 15034
# Unnamed: 0             15035
# data                     0.0
# date              2005-02-26
# param          Precipitation
# siteid           Rhinelander
# Name: 15034, dtype: object
# 15035
# Unnamed: 0             15036
# data                    0.72
# date              2005-02-27
# param          Precipitation
# siteid             Rosemount
# Name: 15035, dtype: object
# 15036
# Unnamed: 0             15037
# data                    0.56
# date              2005-02-28
# param          Precipitation
# siteid               Sanilac
# Name: 15036, dtype: object
# 15037
# Unnamed: 0             15038
# data                     0.0
# date              2005-03-01
# param          Precipitation
# siteid                 SEPAC
# Name: 15037, dtype: object
# 15038
# Unnamed: 0             15039
# data                     0.0
# date              2005-03-02
# param          Precipitation
# siteid               Seymour
# Name: 15038, dtype: object
# 15039
# Unnamed: 0             15040
# data                     0.0
# date              2005-03-03
# param          Precipitation
# siteid            Sutherland
# Name: 15039, dtype: object
# 15040
# Unnamed: 0             15041
# data                     0.0
# date              2005-03-04
# param          Precipitation
# siteid                Urbana
# Name: 15040, dtype: object
# 15041
# Unnamed: 0             15042
# data                     0.0
# date              2005-03-05
# param          Precipitation
# siteid              Walworth
# Name: 15041, dtype: object
# 15042
# Unnamed: 0             15043
# data                     0.0
# date              2005-03-06
# param          Precipitation
# siteid                  ACRE
# Name: 15042, dtype: object
# 15043
# Unnamed: 0             15044
# data                     0.0
# date              2005-03-07
# param          Precipitation
# siteid             AlbertLea
# Name: 15043, dtype: object
# 15044
# Unnamed: 0             15045
# data                     0.0
# date              2005-03-08
# param          Precipitation
# siteid                  Ames
# Name: 15044, dtype: object
# 15045
# Unnamed: 0             15046
# data                     0.0
# date              2005-03-09
# param          Precipitation
# siteid                Antigo
# Name: 15045, dtype: object
# 15046
# Unnamed: 0             15047
# data                    2.11
# date              2005-03-10
# param          Precipitation
# siteid              Appleton
# Name: 15046, dtype: object
# 15047
# Unnamed: 0             15048
# data                    0.74
# date              2005-03-11
# param          Precipitation
# siteid             Arlington
# Name: 15047, dtype: object
# 15048
# Unnamed: 0             15049
# data                    0.17
# date              2005-03-12
# param          Precipitation
# siteid             Bean&Beet
# Name: 15048, dtype: object
# 15049
# Unnamed: 0             15050
# data                     0.0
# date              2005-03-13
# param          Precipitation
# siteid             Brookings
# Name: 15049, dtype: object
# 15050
# Unnamed: 0             15051
# data                     0.0
# date              2005-03-14
# param          Precipitation
# siteid            Brownstown
# Name: 15050, dtype: object
# 15051
# Unnamed: 0             15052
# data                     0.0
# date              2005-03-15
# param          Precipitation
# siteid              Columbia
# Name: 15051, dtype: object
# 15052
# Unnamed: 0             15053
# data                     0.0
# date              2005-03-16
# param          Precipitation
# siteid             Crookston
# Name: 15052, dtype: object
# 15053
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 5
#       3 for index, rows in weather.iterrows():
#       4     print(index)
# ----> 5     print(rows)
#
# File ~/Desktop/pandas/venv/lib/python3.9/site-packages/pandas/core/series.py:1784, in Series.__repr__(self)
#    1782 # pylint: disable=invalid-repr-returned
#    1783 repr_params = fmt.get_series_repr_params()
# -> 1784 return self.to_string(**repr_params)
#
# File ~/Desktop/pandas/venv/lib/python3.9/site-packages/pandas/core/series.py:1883, in Series.to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1831 """
#    1832 Render a string representation of the Series.
#    1833
#    (...)
#    1869 '0    1\\n1    2\\n2    3'
#    1870 """
#    1871 formatter = fmt.SeriesFormatter(
#    1872     self,
#    1873     name=name,
#    (...)
#    1881     max_rows=max_rows,
#    1882 )
# -> 1883 result = formatter.to_string()
#    1885 # catch contract violations
#    1886 if not isinstance(result, str):
#
# File ~/Desktop/pandas/venv/lib/python3.9/site-packages/pandas/io/formats/format.py:319, in SeriesFormatter.to_string(self)
#     317     fmt_index = adj.adjoin(2, *fmt_index).split("\n")
#     318 else:
# --> 319     fmt_index = index._format_flat(include_name=True)
#     320 fmt_values = self._get_formatted_values()
#     322 if self.is_truncated_vertically:
#
# File ~/Desktop/pandas/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:1446, in Index._format_flat(self, include_name, formatter)
#    1443 if formatter is not None:
#    1444     return header + list(self.map(formatter))
# -> 1446 return self._format_with_header(header=header, na_rep=self._default_na_rep)
#
# File ~/Desktop/pandas/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:1465, in Index._format_with_header(self, header, na_rep)
#    1461     justify = "left"
#    1462 # passing leading_space=False breaks test_format_missing,
#    1463 #  test_index_repr_in_frame_with_nan, but would otherwise make
#    1464 #  trim_front unnecessary
# -> 1465 formatted = format_array(values, None, justify=justify)
#    1466 result = trim_front(formatted)
#    1467 return header + result
#
# File ~/Desktop/pandas/venv/lib/python3.9/site-packages/pandas/io/formats/format.py:1161, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting, fallback_formatter)
#    1145     digits = get_option("display.precision")
#    1147 fmt_obj = fmt_klass(
#    1148     values,
#    1149     digits=digits,
#    (...)
#    1158     fallback_formatter=fallback_formatter,
#    1159 )
# -> 1161 return fmt_obj.get_result()
#
# File ~/Desktop/pandas/venv/lib/python3.9/site-packages/pandas/io/formats/format.py:1194, in _GenericArrayFormatter.get_result(self)
#    1193 def get_result(self) -> list[str]:
# -> 1194     fmt_values = self._format_strings()
#    1195     return _make_fixed_width(fmt_values, self.justify)
#
# File ~/Desktop/pandas/venv/lib/python3.9/site-packages/pandas/io/formats/format.py:1259, in _GenericArrayFormatter._format_strings(self)
#    1257 for i, v in enumerate(vals):
#    1258     if (not is_float_type[i] or self.formatter is not None) and leading_space:
# -> 1259         fmt_values.append(f" {_format(v)}")
#    1260     elif is_float_type[i]:
#    1261         fmt_values.append(float_format(v))
#
# File ~/Desktop/pandas/venv/lib/python3.9/site-packages/pandas/io/formats/format.py:1221, in _GenericArrayFormatter._format_strings.<locals>._format(x)
#    1220 def _format(x):
# -> 1221     if self.na_rep is not None and is_scalar(x) and isna(x):
#    1222         if x is None:
#    1223             return "None"
#
# KeyboardInterrupt:

# %% [markdown]
# # Filtering data
